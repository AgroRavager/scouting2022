# %%
import server.tba as tba
import importlib

# %%
importlib.reload(server.tba)
# Out:
# <module 'server.tba' from 'C:\\Users\\shaur\\Python\\scouting\\scouting2022\\scouter\\server\\tba.py'>

# %%
tba.get_matches("2022wasam")
# Out:
# [{'actual_time': 1647813218,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 50,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1899', 'frc492', 'frc948']},
#    'red': {'dq_team_keys': [],
#     'score': 64,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5827', 'frc4911', 'frc1294']}},
#   'comp_level': 'f',
#   'event_key': '2022wasam',
#   'key': '2022wasam_f1m1',
#   'match_number': 1,
#   'predicted_time': 1647814026,
#   'set_number': 1,
#   'time': 1647813960,
#   'winning_alliance': 'red'},
#  {'actual_time': 1647814131,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 62,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1899', 'frc492', 'frc948']},
#    'red': {'dq_team_keys': [],
#     'score': 43,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5827', 'frc4911', 'frc1294']}},
#   'comp_level': 'f',
#   'event_key': '2022wasam',
#   'key': '2022wasam_f1m2',
#   'match_number': 2,
# ...
